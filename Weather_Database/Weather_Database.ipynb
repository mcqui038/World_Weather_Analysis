# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | saint-georges
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | jacareacanga
# Processing Record 7 of Set 1 | kununurra
# Processing Record 8 of Set 1 | lompoc
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | quatre cocos
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | chapais
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | dalby
# Processing Record 18 of Set 1 | luau
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | hofn
# Processing Record 21 of Set 1 | lubango
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | northam
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | grand gaube
# Processing Record 28 of Set 1 | kaeo
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | krasnoselkup
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | goderich
# Processing Record 33 of Set 1 | port lincoln
# Processing Record 34 of Set 1 | bandarbeyla
# Processing Record 35 of Set 1 | mineiros
# Processing Record 36 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 1 | ahipara
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | whitehorse
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | port hardy
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | harper
# Processing Record 47 of Set 1 | la cruz
# Processing Record 48 of Set 1 | chitral
# Processing Record 49 of Set 1 | bilibino
# Processing Record 50 of Set 1 | nakamura
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | rocha
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | sabang
# Processing Record 12 of Set 2 | lahat
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | tanete
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | bisho
# Processing Record 19 of Set 2 | dalaba
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | nova granada
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | broken hill
# Processing Record 30 of Set 2 | diffa
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | general roca
# Processing Record 34 of Set 2 | shimoda
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | beloha
# Processing Record 37 of Set 2 | skelleftea
# Processing Record 38 of Set 2 | aykhal
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | poya
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | rorvik
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | aranos
# Processing Record 46 of Set 2 | karhal
# Processing Record 47 of Set 2 | ikwiriri
# Processing Record 48 of Set 2 | nantucket
# Processing Record 49 of Set 2 | wamba
# Processing Record 50 of Set 2 | naze
# Processing Record 1 of Set 3 | kochubey
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | sandwick
# Processing Record 8 of Set 3 | seoul
# Processing Record 9 of Set 3 | mana
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | itarema
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | erzin
# Processing Record 15 of Set 3 | hualmay
# Processing Record 16 of Set 3 | am timan
# Processing Record 17 of Set 3 | safaga
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | havoysund
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | parabel
# Processing Record 24 of Set 3 | mezhdurechensk
# Processing Record 25 of Set 3 | freeport
# Processing Record 26 of Set 3 | puerto quijarro
# Processing Record 27 of Set 3 | joshimath
# Processing Record 28 of Set 3 | khandbari
# Processing Record 29 of Set 3 | piacabucu
# Processing Record 30 of Set 3 | port hawkesbury
# Processing Record 31 of Set 3 | dutse
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | churapcha
# Processing Record 35 of Set 3 | fairbanks
# Processing Record 36 of Set 3 | atar
# Processing Record 37 of Set 3 | juneau
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | havre-saint-pierre
# Processing Record 41 of Set 3 | hay river
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | morondava
# Processing Record 44 of Set 3 | constantine
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | amahai
# Processing Record 47 of Set 3 | darnah
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | rudnogorsk
# Processing Record 50 of Set 3 | mount gambier
# Processing Record 1 of Set 4 | hilo
# Processing Record 2 of Set 4 | pochutla
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | lekoni
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | ratnagiri
# Processing Record 8 of Set 4 | namatanai
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | tibati
# Processing Record 12 of Set 4 | borgarnes
# Processing Record 13 of Set 4 | labuhan
# Processing Record 14 of Set 4 | ochtrup
# Processing Record 15 of Set 4 | warrnambool
# Processing Record 16 of Set 4 | palana
# Processing Record 17 of Set 4 | san policarpo
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | chore
# City not found. Skipping...
# Processing Record 20 of Set 4 | port blair
# Processing Record 21 of Set 4 | fengrun
# Processing Record 22 of Set 4 | iisalmi
# Processing Record 23 of Set 4 | maumere
# Processing Record 24 of Set 4 | casper
# Processing Record 25 of Set 4 | la plata
# Processing Record 26 of Set 4 | sibu
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | biak
# Processing Record 29 of Set 4 | naliya
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | impfondo
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | flinders
# Processing Record 34 of Set 4 | fatezh
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | jackson
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | arman
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | dumabato
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | berat
# Processing Record 44 of Set 4 | carberry
# Processing Record 45 of Set 4 | boguchany
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | solnechnyy
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | tiznit
# Processing Record 1 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | falam
# Processing Record 4 of Set 5 | kalangala
# Processing Record 5 of Set 5 | abu samrah
# Processing Record 6 of Set 5 | lyuban
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | linxia
# Processing Record 11 of Set 5 | natal
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | sinnamary
# Processing Record 15 of Set 5 | kurayoshi
# Processing Record 16 of Set 5 | la rioja
# Processing Record 17 of Set 5 | mehamn
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | oistins
# Processing Record 21 of Set 5 | warrington
# Processing Record 22 of Set 5 | atasu
# Processing Record 23 of Set 5 | dubenskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 5 | turukhansk
# Processing Record 28 of Set 5 | axim
# Processing Record 29 of Set 5 | morros
# Processing Record 30 of Set 5 | independence
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | aklavik
# Processing Record 34 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 35 of Set 5 | port augusta
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | mosetse
# Processing Record 39 of Set 5 | agadir
# Processing Record 40 of Set 5 | kloulklubed
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | kadoshkino
# Processing Record 43 of Set 5 | nizhniy tsasuchey
# Processing Record 44 of Set 5 | portland
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | babaeski
# Processing Record 49 of Set 5 | koungou
# Processing Record 50 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 6 | kirakira
# Processing Record 2 of Set 6 | inuvik
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | santa maria da vitoria
# Processing Record 5 of Set 6 | nipawin
# Processing Record 6 of Set 6 | meghri
# Processing Record 7 of Set 6 | siteki
# Processing Record 8 of Set 6 | mamontovo
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | romanu
# Processing Record 12 of Set 6 | half moon bay
# Processing Record 13 of Set 6 | nichinan
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 6 | chalmette
# Processing Record 17 of Set 6 | nicolas bravo
# Processing Record 18 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 6 | smithers
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | almaznyy
# Processing Record 22 of Set 6 | flin flon
# Processing Record 23 of Set 6 | ojinaga
# Processing Record 24 of Set 6 | oudtshoorn
# Processing Record 25 of Set 6 | ibra
# Processing Record 26 of Set 6 | kargasok
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | prescott
# Processing Record 29 of Set 6 | nizhniy kuranakh
# Processing Record 30 of Set 6 | necochea
# Processing Record 31 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 6 | palmer
# Processing Record 33 of Set 6 | khash
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 36 of Set 6 | morehead
# Processing Record 37 of Set 6 | birjand
# Processing Record 38 of Set 6 | chilac
# City not found. Skipping...
# Processing Record 39 of Set 6 | fredericksburg
# Processing Record 40 of Set 6 | tabuk
# Processing Record 41 of Set 6 | tilichiki
# Processing Record 42 of Set 6 | suleja
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 6 | damavand
# Processing Record 47 of Set 6 | saint-paul
# Processing Record 48 of Set 6 | severo-kurilsk
# Processing Record 49 of Set 6 | upernavik
# Processing Record 50 of Set 6 | ostrovnoy
# Processing Record 1 of Set 7 | bressanone
# Processing Record 2 of Set 7 | paamiut
# Processing Record 3 of Set 7 | moron
# Processing Record 4 of Set 7 | pombas
# Processing Record 5 of Set 7 | rio gallegos
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | qurayyat
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | opuwo
# Processing Record 10 of Set 7 | khoy
# Processing Record 11 of Set 7 | shinpokh
# Processing Record 12 of Set 7 | houma
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | hami
# Processing Record 15 of Set 7 | marsabit
# Processing Record 16 of Set 7 | tual
# Processing Record 17 of Set 7 | goroka
# Processing Record 18 of Set 7 | hutchinson
# Processing Record 19 of Set 7 | blackwater
# Processing Record 20 of Set 7 | zyryanka
# Processing Record 21 of Set 7 | sur
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | padang
# Processing Record 24 of Set 7 | vanimo
# Processing Record 25 of Set 7 | college
# Processing Record 26 of Set 7 | peniche
# Processing Record 27 of Set 7 | tabou
# Processing Record 28 of Set 7 | mossendjo
# Processing Record 29 of Set 7 | manokwari
# Processing Record 30 of Set 7 | aguimes
# Processing Record 31 of Set 7 | shubarkuduk
# Processing Record 32 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 7 | posse
# Processing Record 34 of Set 7 | marabba
# Processing Record 35 of Set 7 | comodoro rivadavia
# Processing Record 36 of Set 7 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | manmad
# Processing Record 39 of Set 7 | ixtapa
# Processing Record 40 of Set 7 | ust-tsilma
# Processing Record 41 of Set 7 | acapulco
# Processing Record 42 of Set 7 | lazaro cardenas
# Processing Record 43 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | kyzyl-mazhalyk
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | hambantota
# Processing Record 48 of Set 7 | doctor juan leon mallorquin
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | male
# Processing Record 1 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 8 | garowe
# Processing Record 3 of Set 8 | faanui
# Processing Record 4 of Set 8 | tortoli
# Processing Record 5 of Set 8 | eureka
# Processing Record 6 of Set 8 | kamina
# Processing Record 7 of Set 8 | yerofey pavlovich
# Processing Record 8 of Set 8 | port-gentil
# Processing Record 9 of Set 8 | chabahar
# Processing Record 10 of Set 8 | zhezkazgan
# Processing Record 11 of Set 8 | suntar
# Processing Record 12 of Set 8 | nechi
# Processing Record 13 of Set 8 | hun
# Processing Record 14 of Set 8 | qaqortoq
# Processing Record 15 of Set 8 | camana
# Processing Record 16 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 17 of Set 8 | constitucion
# Processing Record 18 of Set 8 | tafresh
# Processing Record 19 of Set 8 | vao
# Processing Record 20 of Set 8 | la orilla
# Processing Record 21 of Set 8 | dunedin
# Processing Record 22 of Set 8 | traverse city
# Processing Record 23 of Set 8 | baiquan
# Processing Record 24 of Set 8 | ovalle
# Processing Record 25 of Set 8 | devonport
# Processing Record 26 of Set 8 | tavda
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | mandan
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | grafton
# Processing Record 32 of Set 8 | pevek
# Processing Record 33 of Set 8 | talara
# Processing Record 34 of Set 8 | zhangye
# Processing Record 35 of Set 8 | faya
# Processing Record 36 of Set 8 | corner brook
# Processing Record 37 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | prince rupert
# Processing Record 40 of Set 8 | alihe
# Processing Record 41 of Set 8 | dolores
# Processing Record 42 of Set 8 | zhigansk
# Processing Record 43 of Set 8 | nanning
# Processing Record 44 of Set 8 | ambilobe
# Processing Record 45 of Set 8 | shieli
# Processing Record 46 of Set 8 | goure
# Processing Record 47 of Set 8 | krasnaya gorbatka
# Processing Record 48 of Set 8 | mpongwe
# Processing Record 49 of Set 8 | saint anthony
# Processing Record 50 of Set 8 | najran
# Processing Record 1 of Set 9 | kijang
# Processing Record 2 of Set 9 | hattiesburg
# Processing Record 3 of Set 9 | nara
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | pemberton
# Processing Record 6 of Set 9 | savignano sul rubicone
# Processing Record 7 of Set 9 | marang
# Processing Record 8 of Set 9 | ferrol
# Processing Record 9 of Set 9 | novopetrovskoye
# Processing Record 10 of Set 9 | genhe
# Processing Record 11 of Set 9 | kasongo
# Processing Record 12 of Set 9 | nkoteng
# Processing Record 13 of Set 9 | lerwick
# Processing Record 14 of Set 9 | bara
# Processing Record 15 of Set 9 | huarmey
# Processing Record 16 of Set 9 | leshukonskoye
# Processing Record 17 of Set 9 | airai
# Processing Record 18 of Set 9 | ngunguru
# Processing Record 19 of Set 9 | lloydminster
# Processing Record 20 of Set 9 | predivinsk
# Processing Record 21 of Set 9 | kidal
# Processing Record 22 of Set 9 | balakhta
# Processing Record 23 of Set 9 | dudinka
# Processing Record 24 of Set 9 | tharad
# Processing Record 25 of Set 9 | ulladulla
# Processing Record 26 of Set 9 | dubbo
# Processing Record 27 of Set 9 | baherden
# Processing Record 28 of Set 9 | koumac
# Processing Record 29 of Set 9 | yumen
# Processing Record 30 of Set 9 | nemuro
# Processing Record 31 of Set 9 | akdepe
# Processing Record 32 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 9 | zhireken
# Processing Record 34 of Set 9 | vostok
# Processing Record 35 of Set 9 | maragogi
# Processing Record 36 of Set 9 | chajul
# Processing Record 37 of Set 9 | sao filipe
# Processing Record 38 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 39 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 9 | svay rieng
# Processing Record 41 of Set 9 | puerto maldonado
# Processing Record 42 of Set 9 | kasama
# Processing Record 43 of Set 9 | chalus
# Processing Record 44 of Set 9 | hirara
# Processing Record 45 of Set 9 | preobrazheniye
# Processing Record 46 of Set 9 | kamaishi
# Processing Record 47 of Set 9 | seddon
# Processing Record 48 of Set 9 | saldanha
# Processing Record 49 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 9 | ninotsminda
# Processing Record 1 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 10 | pobe
# Processing Record 3 of Set 10 | awbari
# Processing Record 4 of Set 10 | mnogovershinnyy
# Processing Record 5 of Set 10 | pokhara
# Processing Record 6 of Set 10 | bako
# Processing Record 7 of Set 10 | khalkhal
# Processing Record 8 of Set 10 | porto novo
# Processing Record 9 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 10 | arica
# Processing Record 11 of Set 10 | dovers
# Processing Record 12 of Set 10 | lahaina
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | brokopondo
# Processing Record 15 of Set 10 | calama
# Processing Record 16 of Set 10 | shenjiamen
# Processing Record 17 of Set 10 | kaspiysk
# Processing Record 18 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | port macquarie
# Processing Record 20 of Set 10 | anda
# Processing Record 21 of Set 10 | praia da vitoria
# Processing Record 22 of Set 10 | biryusinsk
# Processing Record 23 of Set 10 | bereda
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | luderitz
# Processing Record 26 of Set 10 | nishihara
# Processing Record 27 of Set 10 | almenevo
# City not found. Skipping...
# Processing Record 28 of Set 10 | senanga
# Processing Record 29 of Set 10 | kumano
# Processing Record 30 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 10 | kyaikto
# Processing Record 32 of Set 10 | gillette
# Processing Record 33 of Set 10 | tazovskiy
# Processing Record 34 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 10 | mumford
# Processing Record 36 of Set 10 | luganville
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | namibe
# Processing Record 39 of Set 10 | moscow
# Processing Record 40 of Set 10 | pavlovka
# Processing Record 41 of Set 10 | itanhem
# Processing Record 42 of Set 10 | westport
# Processing Record 43 of Set 10 | chernyshevskiy
# Processing Record 44 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 10 | folsom
# Processing Record 46 of Set 10 | tautira
# Processing Record 47 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 48 of Set 10 | reconquista
# Processing Record 49 of Set 10 | sobolevo
# Processing Record 50 of Set 10 | khorixas
# Processing Record 1 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 2 of Set 11 | mlawa
# Processing Record 3 of Set 11 | paita
# Processing Record 4 of Set 11 | komotini
# Processing Record 5 of Set 11 | los llanos de aridane
# Processing Record 6 of Set 11 | haines junction
# Processing Record 7 of Set 11 | otjiwarongo
# Processing Record 8 of Set 11 | broome
# Processing Record 9 of Set 11 | tessalit
# Processing Record 10 of Set 11 | mobaye
# Processing Record 11 of Set 11 | kudat
# Processing Record 12 of Set 11 | suez
# Processing Record 13 of Set 11 | sept-iles
# Processing Record 14 of Set 11 | blagoyevo
# Processing Record 15 of Set 11 | milazzo
# Processing Record 16 of Set 11 | cuenca
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | methven
# Processing Record 19 of Set 11 | wladyslawowo
# Processing Record 20 of Set 11 | lianzhou
# Processing Record 21 of Set 11 | mazagao
# Processing Record 22 of Set 11 | labranzagrande
# Processing Record 23 of Set 11 | dauphin
# Processing Record 24 of Set 11 | muros
# Processing Record 25 of Set 11 | bulgan
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | bubaque
# Processing Record 28 of Set 11 | nouakchott
# Processing Record 29 of Set 11 | eyl
# Processing Record 30 of Set 11 | sechura
# Processing Record 31 of Set 11 | diphu
# Processing Record 32 of Set 11 | morro bay
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | urengoy
# Processing Record 35 of Set 11 | balila
# Processing Record 36 of Set 11 | qiongshan
# Processing Record 37 of Set 11 | zacacalco
# City not found. Skipping...
# Processing Record 38 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 11 | sabancuy
# Processing Record 41 of Set 11 | waipawa
# Processing Record 42 of Set 11 | durban
# Processing Record 43 of Set 11 | karangasem
# Processing Record 44 of Set 11 | wahpeton
# Processing Record 45 of Set 11 | maniitsoq
# Processing Record 46 of Set 11 | halifax
# Processing Record 47 of Set 11 | tamuin
# Processing Record 48 of Set 11 | pampierstad
# Processing Record 49 of Set 11 | margate
# Processing Record 50 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | toccoa
# Processing Record 4 of Set 12 | aksarka
# Processing Record 5 of Set 12 | mitsamiouli
# Processing Record 6 of Set 12 | salym
# Processing Record 7 of Set 12 | weatherford
# Processing Record 8 of Set 12 | ampanihy
# Processing Record 9 of Set 12 | novoorsk
# Processing Record 10 of Set 12 | springbok
# Processing Record 11 of Set 12 | monrovia
# Processing Record 12 of Set 12 | uyemskiy
# Processing Record 13 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 14 of Set 12 | sao miguel do araguaia
# Processing Record 15 of Set 12 | shingu
# Processing Record 16 of Set 12 | mahajanga
# Processing Record 17 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 18 of Set 12 | adrar
# Processing Record 19 of Set 12 | alugan
# Processing Record 20 of Set 12 | taksimo
# Processing Record 21 of Set 12 | vardo
# Processing Record 22 of Set 12 | nehe
# Processing Record 23 of Set 12 | te anau
# Processing Record 24 of Set 12 | ambon
# Processing Record 25 of Set 12 | asfi
# Processing Record 26 of Set 12 | bojnurd
# Processing Record 27 of Set 12 | sorland
# Processing Record 28 of Set 12 | pointe michel
# Processing Record 29 of Set 12 | kutum
# Processing Record 30 of Set 12 | mildura
# Processing Record 31 of Set 12 | cabedelo
# Processing Record 32 of Set 12 | hetauda
# Processing Record 33 of Set 12 | ouadda
# Processing Record 34 of Set 12 | ternate
# Processing Record 35 of Set 12 | paddaya
# Processing Record 36 of Set 12 | nador
# Processing Record 37 of Set 12 | belaya gora
# Processing Record 38 of Set 12 | brae
# Processing Record 39 of Set 12 | koslan
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | pemba
# Processing Record 42 of Set 12 | labrea
# Processing Record 43 of Set 12 | avanigadda
# Processing Record 44 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 45 of Set 12 | aitape
# Processing Record 46 of Set 12 | lamu
# Processing Record 47 of Set 12 | san quintin
# Processing Record 48 of Set 12 | calamar
# Processing Record 49 of Set 12 | santo anastacio
# Processing Record 50 of Set 12 | kalengwa
# Processing Record 1 of Set 13 | ishigaki
# Processing Record 2 of Set 13 | barpali
# Processing Record 3 of Set 13 | bilokurakyne
# Processing Record 4 of Set 13 | shaunavon
# Processing Record 5 of Set 13 | voh
# Processing Record 6 of Set 13 | cururupu
# Processing Record 7 of Set 13 | olafsvik
# Processing Record 8 of Set 13 | gomez palacio
# Processing Record 9 of Set 13 | zima
# Processing Record 10 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 13 | mahibadhoo
# Processing Record 12 of Set 13 | kokopo
# Processing Record 13 of Set 13 | zheshart
# Processing Record 14 of Set 13 | tabas
# Processing Record 15 of Set 13 | severomuysk
# Processing Record 16 of Set 13 | opotiki
# Processing Record 17 of Set 13 | barcelos
# Processing Record 18 of Set 13 | kongwa
# Processing Record 19 of Set 13 | richards bay
# Processing Record 20 of Set 13 | chiredzi
# Processing Record 21 of Set 13 | bolgatanga
# Processing Record 22 of Set 13 | kirkland lake
# Processing Record 23 of Set 13 | kita
# Processing Record 24 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 25 of Set 13 | tyrma
# Processing Record 26 of Set 13 | garoua
# Processing Record 27 of Set 13 | maldonado
# Processing Record 28 of Set 13 | tommot
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | asau
# Processing Record 31 of Set 13 | mancio lima
# Processing Record 32 of Set 13 | tallahassee
# Processing Record 33 of Set 13 | jamkhandi
# Processing Record 34 of Set 13 | omboue
# Processing Record 35 of Set 13 | serov
# Processing Record 36 of Set 13 | burlatskoye
# Processing Record 37 of Set 13 | katha
# City not found. Skipping...
# Processing Record 38 of Set 13 | trabzon
# Processing Record 39 of Set 13 | kiunga
# Processing Record 40 of Set 13 | warmbad
# Processing Record 41 of Set 13 | bousso
# Processing Record 42 of Set 13 | vichuga
# Processing Record 43 of Set 13 | totness
# Processing Record 44 of Set 13 | bandiagara
# Processing Record 45 of Set 13 | nyurba
# Processing Record 46 of Set 13 | teguldet
# Processing Record 47 of Set 13 | newport
# Processing Record 48 of Set 13 | mahon
# Processing Record 49 of Set 13 | sai buri
# Processing Record 50 of Set 13 | vizinga
# Processing Record 1 of Set 14 | taloqan
# Processing Record 2 of Set 14 | tres arroyos
# Processing Record 3 of Set 14 | praia
# Processing Record 4 of Set 14 | makat
# Processing Record 5 of Set 14 | charters towers
# Processing Record 6 of Set 14 | carnot
# Processing Record 7 of Set 14 | davenport
# Processing Record 8 of Set 14 | samarinda
# Processing Record 9 of Set 14 | yulara
# Processing Record 10 of Set 14 | mao
# Processing Record 11 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 14 | bialystok
# Processing Record 13 of Set 14 | phalodi
# Processing Record 14 of Set 14 | kingisepp
# Processing Record 15 of Set 14 | narsaq
# Processing Record 16 of Set 14 | pecos
# Processing Record 17 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 18 of Set 14 | beli potok
# Processing Record 19 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 14 | alice springs
# Processing Record 22 of Set 14 | big bend
# Processing Record 23 of Set 14 | hanmer springs
# Processing Record 24 of Set 14 | nouadhibou
# Processing Record 25 of Set 14 | bonthe
# Processing Record 26 of Set 14 | pangody
# Processing Record 27 of Set 14 | baykit
# Processing Record 28 of Set 14 | svetlyy
# Processing Record 29 of Set 14 | ballina
# Processing Record 30 of Set 14 | nunkini
# Processing Record 31 of Set 14 | viedma
# Processing Record 32 of Set 14 | jining
# Processing Record 33 of Set 14 | nago
# Processing Record 34 of Set 14 | lanipao
# Processing Record 35 of Set 14 | roald
# Processing Record 36 of Set 14 | umm lajj
# Processing Record 37 of Set 14 | san ignacio
# Processing Record 38 of Set 14 | banon
# Processing Record 39 of Set 14 | astoria
# Processing Record 40 of Set 14 | bac lieu
# Processing Record 41 of Set 14 | uwajima
# Processing Record 42 of Set 14 | xinzhou
# Processing Record 43 of Set 14 | bhimunipatnam
# Processing Record 44 of Set 14 | salta
# Processing Record 45 of Set 14 | arlit
# Processing Record 46 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 14 | canutama
# Processing Record 48 of Set 14 | booue
# Processing Record 49 of Set 14 | kamenka
# Processing Record 50 of Set 14 | fortuna
# Processing Record 1 of Set 15 | riaba
# City not found. Skipping...
# Processing Record 2 of Set 15 | pareora
# Processing Record 3 of Set 15 | taoudenni
# Processing Record 4 of Set 15 | mulchen
# Processing Record 5 of Set 15 | san juan cotzal
# Processing Record 6 of Set 15 | aviles
# Processing Record 7 of Set 15 | gilgit
# Processing Record 8 of Set 15 | okhotsk
# Processing Record 9 of Set 15 | camopi
# Processing Record 10 of Set 15 | mwinilunga
# Processing Record 11 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 15 | irbil
# Processing Record 13 of Set 15 | ketchikan
# Processing Record 14 of Set 15 | tashtagol
# Processing Record 15 of Set 15 | olinda
# Processing Record 16 of Set 15 | tsevie
# Processing Record 17 of Set 15 | ahaus
# Processing Record 18 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 15 | verkhoyansk
# Processing Record 20 of Set 15 | beni suef
# Processing Record 21 of Set 15 | sheridan
# Processing Record 22 of Set 15 | inhambane
# Processing Record 23 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | nuuk
# Processing Record 25 of Set 15 | bell ville
# Processing Record 26 of Set 15 | visnes
# Processing Record 27 of Set 15 | kolokani
# Processing Record 28 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 15 | canala
# Processing Record 30 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 15 | sao sebastiao
# Processing Record 32 of Set 15 | marawi
# Processing Record 33 of Set 15 | bowmore
# Processing Record 34 of Set 15 | roma
# Processing Record 35 of Set 15 | brownwood
# Processing Record 36 of Set 15 | rabak
# Processing Record 37 of Set 15 | mongagua
# Processing Record 38 of Set 15 | jefferson city
# Processing Record 39 of Set 15 | okha
# Processing Record 40 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 41 of Set 15 | shahr-e kord
# Processing Record 42 of Set 15 | duz
# City not found. Skipping...
# Processing Record 43 of Set 15 | lodja
# Processing Record 44 of Set 15 | kerrobert
# Processing Record 45 of Set 15 | atambua
# Processing Record 46 of Set 15 | kindberg
# Processing Record 47 of Set 15 | nueva loja
# Processing Record 48 of Set 15 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Hermanus -34.4187   19.2345     71.80     overcast clouds        84
# 1        Busselton -33.6500  115.3333     57.09           clear sky        69
# 2     Beringovskiy  63.0500  179.3167    -25.89          few clouds        95
# 3    Saint-Georges  12.0564  -61.7485     83.88       broken clouds        70
# 4  Bambous Virieux -20.3428   57.7575     78.22    scattered clouds        81
# 5     Jacareacanga  -6.2222  -57.7528     83.80     overcast clouds        83
# 6        Kununurra -15.7667  128.7333     78.78          few clouds        94
# 7           Lompoc  34.6391 -120.4579     80.08           clear sky        34
# 8     Punta Arenas -53.1500  -70.9167     55.15       broken clouds        50
# 9     Quatre Cocos -20.2078   57.7625     80.71          light rain        81
#
#    Cloudiness  Wind Speed Country
# 0          96        6.53      ZA
# 1           0       14.09      AU
# 2          23        7.56      RU
# 3          75       20.71      GD
# 4          47        7.52      MU
# 5          91        2.93      BR
# 6          13        2.30      AU
# 7          10        2.48      US
# 8          57       23.87      CL
# 9          61        8.12      MU

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus      ZA -34.4187   19.2345     71.80        84          96
# 1        Busselton      AU -33.6500  115.3333     57.09        69           0
# 2     Beringovskiy      RU  63.0500  179.3167    -25.89        95          23
# 3    Saint-Georges      GD  12.0564  -61.7485     83.88        70          75
# 4  Bambous Virieux      MU -20.3428   57.7575     78.22        81          47
# 5     Jacareacanga      BR  -6.2222  -57.7528     83.80        83          91
# 6        Kununurra      AU -15.7667  128.7333     78.78        94          13
# 7           Lompoc      US  34.6391 -120.4579     80.08        34          10
# 8     Punta Arenas      CL -53.1500  -70.9167     55.15        50          57
# 9     Quatre Cocos      MU -20.2078   57.7625     80.71        81          61
#
#    Wind Speed Current Description
# 0        6.53     overcast clouds
# 1       14.09           clear sky
# 2        7.56          few clouds
# 3       20.71       broken clouds
# 4        7.52    scattered clouds
# 5        2.93     overcast clouds
# 6        2.30          few clouds
# 7        2.48           clear sky
# 8       23.87       broken clouds
# 9        8.12          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
